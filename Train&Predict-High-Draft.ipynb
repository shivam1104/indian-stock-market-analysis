# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library  
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import time

# %%
#Analyse and Predict 
from os import listdir
import pandas as pd


def find_csv_filenames(path_to_dir,suffix=".csv"):
    filenames = listdir(path_to_dir)
    return [ filename for filename in filenames if filename.endswith( suffix ) ]

# %%
path = "AnalysisOn\High\\"
highFiles = find_csv_filenames(path)

# %%
#for i in highFiles:
i=highFiles[0]
print("Currently Running on {}".format(i))
readFile = path+i
df=pd.read_csv(readFile)
df
# Out:
# Currently Running on TechnicalsHighADSL.csv
#             Date         Low       Close   Adj Close   Volume  Dividends  \
# 0     2007-08-22  136.050003  139.250000  131.643997   205812        0.0
# 1     2007-08-23  139.500000  142.399994  134.621918   178972        0.0
# 2     2007-08-24  138.875000  140.000000  132.353027    98378        0.0
# 3     2007-08-27  142.000000  147.500000  139.443359   121738        0.0
# 4     2007-08-28  145.000000  146.500000  138.497986    91634        0.0
# ...          ...         ...         ...         ...      ...        ...
# 3320  2021-02-22   37.500000   38.200001   38.200001    87469        0.0
# 3321  2021-02-23   39.650002   42.000000   42.000000  1119160        0.0
# 3322  2021-02-24   40.500000   40.950001   40.950001   326623        0.0
# 3323  2021-02-25   39.700001   40.000000   40.000000   165001        0.0
# 3324  2021-02-26   38.900002   40.299999   40.299999   139832        0.0
#
#       Stock Splits        EM12        EM26      MACD  ...  momentum_ao  \
# 0              0.0  147.791288  149.658196 -1.866908  ...    -6.297499
# 1              0.0  146.936247  148.987268 -2.051020  ...    -7.102856
# 2              0.0  145.841383  148.171489 -2.330106  ...    -7.603977
# 3              0.0  146.102147  148.111539 -2.009392  ...    -8.763262
# 4              0.0  146.164487  147.969816 -1.805330  ...    -8.268855
# ...            ...         ...         ...       ...  ...          ...
# 3320           0.0   38.704316   38.578901  0.125415  ...    -1.758529
# 3321           0.0   39.211344   38.832316  0.379029  ...    -1.381912
# 3322           0.0   39.478830   38.989181  0.489649  ...    -0.569706
# 3323           0.0   39.559010   39.064057  0.494953  ...    -0.071323
# 3324           0.0   39.673008   39.155608  0.517400  ...     0.429559
#
#       momentum_kama  momentum_roc  momentum_ppo  momentum_ppo_signal  \
# 0        151.325401     -4.948805    -72.011396           -61.329574
# 1        150.700279     -8.129036    -74.003038           -63.864267
# 2        150.198602    -10.799616    -75.991481           -66.289710
# 3        150.174985     -7.523511    -77.721365           -68.576041
# 4        150.079847     -3.364120    -79.363611           -70.733555
# ...             ...           ...           ...                  ...
# 3320      38.607183     -5.093166    -15.726523           -12.074175
# 3321      38.876727      4.868916     25.035929            -4.652154
# 3322      38.948630      4.464286     23.962059             1.070689
# 3323      38.974440      2.695762     18.342583             4.525068
# 3324      38.996589      3.201024     12.801987             6.180451
#
#       momentum_ppo_hist  others_dr  others_dlr  others_cr   Next_High
# 0            -10.681823  -1.206099   -1.213432 -14.491867  145.449997
# 1            -10.138772   2.262114    2.236908 -12.557575  143.449997
# 2             -9.701772  -1.685389   -1.699753 -14.031320  147.500000
# 3             -9.145324   5.357143    5.218575  -9.425855  148.949997
# 4             -8.630057  -0.677966   -0.680275 -10.039917  150.475006
# ...                 ...        ...         ...        ...         ...
# 3320          -3.652349   1.326260    1.317542 -76.542831   42.000000
# 3321          29.688083   9.947642    9.483408 -74.209396   43.750000
# 3322          22.891370  -2.499998   -2.531779 -74.854161   42.450001
# 3323          13.817515  -2.319904   -2.347237 -75.437520   41.549999
# 3324           6.621535   0.749998    0.747200 -75.253302         NaN
#
# [3325 rows x 228 columns]

# %%
final_Pred =
